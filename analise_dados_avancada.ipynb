# %% [markdown]
# # Analise de dados avançada com Python
#
# <p>Neste exemplo estarei realizando uma analise básica e também uma analise mais avançada dos dados, onde verei alguns conceitos de estatisticas e gráficos.<br>
#
# <p>Os dados abaixo representam uma tabela de veiculos com valores e caracteristicas dos modelos.

# %%
# A primeira coisa que temos que fazer é importar os pacotes que iremos utilizar.

#Pandas: Possui inúmeras funções e comandos para importar arquivos, analisar dados, tratar dados, etc.
import pandas as pd

#Matplotlib: Possui uma série de funções e comandos para exibição de gráficos
import matplotlib.pyplot as plt

#Seaborn: Possui uma série de funções e comandos para exibição de gráficos (Visualizações mais robustas do que o Matplotlib)
import seaborn as sns

#Warnings: Possui uma série de funções e comandos para tratamento de mensagens de avisos e alertas do Python
import warnings
warnings.filterwarnings("ignore")

# %%
# Comando para exibir todas colunas do arquivo

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Comando utilizado para carregar o arquivo e armazena-lo como um DataFrame do Pandas
# Um DataFrame do Pandas é como se fosse uma planilha do Excel, onde podemos tratar linhas e colunas.

df_dados = pd.read_excel("dados.xlsx")

# %%
# Comando utilizado para verificar a quantidade de linhas e colunas do arquivo, nesse caso temos 984 linhas e 10 colunas.
# Colunas também são chamadas de variáveis.

df_dados.shape
# Out:
# (984, 10)

# %%
# Comando utilizado para verificar as linhas iniciais do DataFrame

df_dados.head()
# Out:
#   DATA_VENDA         MODELO  KM-LITRO  CILINDROS  PESO(KG)  \
# 0  10/1/2020     LABORGUINI       3.0         12      1200
# 1  10/1/2020        FERRARI       3.0         12      1400
# 2  10/1/2020   ASTON MARTIN       3.5         10      1600
# 3  10/1/2020  MERCEDES SL80       4.5          8      1700
# 4  10/1/2020      HONDA FIT      12.0          4      1700
#
#    VELOCIDADE_MAXIMA(KM/H)  CAVALOS TRANSMISSAO   VALOR  CATEGORIA
# 0                      360      700  AUTOMATICO  900000  IMPORTADO
# 1                      360      640  AUTOMATICO  900000  IMPORTADO
# 2                      360      620  AUTOMATICO  900000  IMPORTADO
# 3                      360      480  AUTOMATICO  800000  IMPORTADO
# 4                      200      116  AUTOMATICO  120000   NACIONAL

# %%
# Comando utilizado para verificar as linhas finais do DataFrame

df_dados.tail()
# Out:
#      DATA_VENDA     MODELO  KM-LITRO  CILINDROS  PESO(KG)  \
# 979  10/12/2021  HONDA FIT      12.0          4      1700
# 980  10/12/2021      PALIO      11.0          4      1700
# 981  10/12/2021        UNO      13.5          4      1700
# 982  10/12/2021       MOBI      14.0          4      1700
# 983  10/12/2021     PASSAT       8.0          6      1800
#
#      VELOCIDADE_MAXIMA(KM/H)  CAVALOS TRANSMISSAO   VALOR  CATEGORIA
# 979                      200      116  AUTOMATICO  120000   NACIONAL
# 980                      200      118      MANUAL   60000   NACIONAL
# 981                      200      118      MANUAL   48000   NACIONAL
# 982                      200      118      MANUAL   42000   NACIONAL
# 983                      200      118      MANUAL  200000  IMPORTADO

# %%
# Avaliar o período dos dados coletados

inicio = pd.to_datetime(df_dados['DATA_VENDA']).dt.date.min()
fim = pd.to_datetime(df_dados['DATA_VENDA']).dt.date.max()
print('Período dos dados - De:', inicio, 'Até:',fim)
# Out:
# Período dos dados - De: 2020-10-01 Até: 2021-10-12

# %%
# Comando utilizado para verificar informações sobre os dados(Tipo de variáveis, Variáveis, Quantidade de registros, etc)

df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DATA_VENDA               984 non-null    object
#  1   MODELO                   984 non-null    object
#  2   KM-LITRO                 984 non-null    float64
#  3   CILINDROS                984 non-null    int64
#  4   PESO(KG)                 984 non-null    int64
#  5   VELOCIDADE_MAXIMA(KM/H)  984 non-null    int64
#  6   CAVALOS                  984 non-null    int64
#  7   TRANSMISSAO              984 non-null    object
#  8   VALOR                    984 non-null    int64
#  9   CATEGORIA                984 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 77.0+ KB

# %%
# Comando utilizado para avaliar se alguma variável possui valor nulo ou chamado de valores missing ou NAN (Not Available)

df_dados.isnull().sum()
# Out:
# DATA_VENDA                 0
# MODELO                     0
# KM-LITRO                   0
# CILINDROS                  0
# PESO(KG)                   0
# VELOCIDADE_MAXIMA(KM/H)    0
# CAVALOS                    0
# TRANSMISSAO                0
# VALOR                      0
# CATEGORIA                  0
# dtype: int64

# %%
# Comando utilizado para fazer uma analise rápida com medidas estatisticas(Média, Mediana, Desvio Padrão, etc)

df_dados.describe()
# Out:
#          KM-LITRO   CILINDROS     PESO(KG)  VELOCIDADE_MAXIMA(KM/H)  \
# count  984.000000  984.000000   984.000000               984.000000
# mean     8.223780    6.103659  1960.975610               255.121951
# std      3.712926    2.754711   458.957933                71.026376
# min      3.000000    3.000000  1200.000000               200.000000
# 25%      4.500000    4.000000  1700.000000               200.000000
# 50%      8.000000    4.000000  1700.000000               200.000000
# 75%     11.000000    8.000000  2300.000000               360.000000
# max     14.000000   12.000000  3000.000000               360.000000
#
#           CAVALOS          VALOR
# count  984.000000     984.000000
# mean   260.024390  297103.658537
# std    203.025136  334160.650302
# min    116.000000   18000.000000
# 25%    118.000000   42000.000000
# 50%    118.000000  120000.000000
# 75%    340.000000  400000.000000
# max    700.000000  900000.000000

# %%
# Outra forma de avaliarmos uma variável especifica e exibirmos a informação. 

print('Valor mínimo: ', df_dados['VALOR'].min())
print('Valor máximo: ', df_dados['VALOR'].max())
print('Valor da média:' , df_dados['VALOR'].mean())
print('Valor da médiana:', df_dados['VALOR'].median())
print('Valor da Moda:', df_dados['VALOR'].mode())
print('Valor da Variancia:', df_dados['VALOR'].var())
# Out:
# Valor mínimo:  18000
# Valor máximo:  900000
# Valor da média: 297103.65853658534
# Valor da médiana: 120000.0
# Valor da Moda: 0    900000
# Name: VALOR, dtype: int64
# Valor da Variancia: 111663340210.40623

# %%
# Média
# A média ou média aritmética, nada mais é do que a soma de todos os dados da amostra dividido pela quantidade de amostras. 

media = df_dados['VALOR'].mean()
print("Média ", media)
# Out:
# Média  297103.65853658534

# %%
# Mediana
# Mediana é o valor representado pela amostra central, estando as amostras ordenadas em valores crescentes, 
# caso o total de elementos for par, será necessário calcular a média dos dois valores centrais. 

mediana = df_dados['VALOR'].median() 
print("Mediana ", mediana)
# Out:
# Mediana  120000.0

# %%
# Moda
# A Moda é o valor que aparece com mais frequência em um conjunto de dados, ou seja, o valor que se repete mais vezes. 

moda = df_dados['VALOR'].mode() 
print("Moda ", moda[0])
# Out:
# Moda  900000

# %%
# Variância
# A variância é uma medida de dispersão dos dados, mede o quão afastados os dados estão da média. 
# Quanto maior a variância, mais afastados os dados encontram-se da média. Assim temos a variância populacional.

variancia = df_dados['VALOR'].var() 
print("Variância ", variancia)
# Out:
# Variância  111663340210.40623

# %%
# Desvio Padrão
# O desvio padrão (standard deviation) é a raiz quadrada da variância. 
# Toda discussão em relação à variância populacional Vs. amostral se aplica, com as devidas mudanças, ao desvio padrão.

desvio = df_dados['VALOR'].std() 
print("Desvio padrão ", desvio)
# Out:
# Desvio padrão  334160.6503022255

# %%
# Quantis
# Quantis são pontos que dividem uma distribuição de probabilidade em partições de tamanhos iguais.  
# Eles podem ser quartis (sendo o 1º quartil correspondente a 25% dos dados, 
# o segundo quartil correspondente a 50% dos dados – a mediana e o 3º quartil correspondente a 75% dos dados) 
# ou percentis (dividem a amostra em 100 partes).

Q1 = df_dados['VALOR'].quantile(0.25)
Q2 = df_dados['VALOR'].quantile(0.5)
Q3 = df_dados['VALOR'].quantile(0.75)
print('Primeiro quartil ', Q1)
print('Segundo quartil (Mediana)', Q2)
print('Terceiro quartil ', Q3)
# Out:
# Primeiro quartil  42000.0
# Segundo quartil (Mediana) 120000.0
# Terceiro quartil  400000.0

# %%
# Intervalo Interquartil (IQR)
# O IQR (do inglês, Interquartile Range), é a diferença entre o terceiro e primeiro quartis: IQR = Q3−Q1. 
# É uma medida de dispersão robusta muito utilizada, por exemplo, quando os dados contêm muitos outliers 
# por ser menos sensível às variações nos extremos do conjunto.
    
IQR = Q3 - Q1
print('Intervalo interquartil ', IQR)
# Out:
# Intervalo interquartil  358000.0

# %%
# Assimetria (Skewness)
# Assimetria é, na verdade, uma medida de simetria. Ela nos diz o quão simétrica é a distribuição dos dados em torno da média. 
# E junto com a curtose (kurtosis) que veremos em seguida, é uma medida muito boa para informar a aparência ou forma da 
# distribuição dos dados.

assimetria = df_dados['VALOR'].skew()
print('Assimetria(Skewness) ', assimetria)
# Out:
# Assimetria(Skewness)  1.0274405638938164

# %%
# Curtose (Kurtosis)
# A Curtose ou achatamento também é uma medida que nos ajuda a dar forma à distribuição dos dados. 
# A curtose, diferente da assimetria, tenta capturar em uma medida a forma das caudas da distribuição.

curtose = df_dados['VALOR'].kurtosis()
print('Curtose ', curtose)
# Out:
# Curtose  -0.6846154705432306

# %%
# Total de valores únicos de cada variável

valores_unicos = []
for i in df_dados.columns[0:14].tolist():
    print(i, ':', len(df_dados[i].astype(str).value_counts()))
    valores_unicos.append(len(df_dados[i].astype(str).value_counts()))
# Out:
# DATA_VENDA : 24
# MODELO : 22
# KM-LITRO : 14
# CILINDROS : 6
# PESO(KG) : 14
# VELOCIDADE_MAXIMA(KM/H) : 5
# CAVALOS : 12
# TRANSMISSAO : 2
# VALOR : 18
# CATEGORIA : 2

# %%
# Verificar quantidade de registros com valor superior a 800.000
# loc é um método fundamental em pandas para selecionar dados em um DataFrame, filtra as linhas onde a condição é True
# Então através do LOC, ele vai olhar para cada linha da coluna VALOR é maior que 800000 e vai contar. 
# Todas as colunas aparecem com o mesmo valor (168) porque o .count() está contando o número de linhas que 
# satisfazem a condição df_dados['VALOR'] > 800000 para cada coluna individualmente, 
# e nesse caso específico, nenhuma dessas linhas tem valores nulos (NaN) nas colunas listadas.

df_dados.loc[df_dados['VALOR'] > 800000].count()
# Out:
# DATA_VENDA                 168
# MODELO                     168
# KM-LITRO                   168
# CILINDROS                  168
# PESO(KG)                   168
# VELOCIDADE_MAXIMA(KM/H)    168
# CAVALOS                    168
# TRANSMISSAO                168
# VALOR                      168
# CATEGORIA                  168
# dtype: int64

# %%
# Quais são os casos com valores superiores a 800.000
# Aqui ele vai mostrar as 168 linhas com o VALOR acima de 800.000 

df_dados.loc[df_dados['VALOR'] > 800000]
# Out:
#      DATA_VENDA        MODELO  KM-LITRO  CILINDROS  PESO(KG)  \
# 0     10/1/2020    LABORGUINI       3.0         12      1200
# 1     10/1/2020       FERRARI       3.0         12      1400
# 2     10/1/2020  ASTON MARTIN       3.5         10      1600
# 22    10/2/2020    LABORGUINI       3.0         12      1200
# 23    10/2/2020       FERRARI       3.0         12      1400
# 24    10/2/2020  ASTON MARTIN       3.5         10      1600
# 35    10/3/2020    LABORGUINI       3.0         12      1200
# 36    10/3/2020       FERRARI       3.0         12      1400
# 37    10/3/2020  ASTON MARTIN       3.5         10      1600
# 57    10/3/2020    LABORGUINI       3.0         12      1200
# 58    10/3/2020       FERRARI       3.0         12      1400
# 59    10/3/2020  ASTON MARTIN       3.5         10      1600
# 79    10/5/2020    LABORGUINI       3.0         12      1200
# 80    10/5/2020       FERRARI       3.0         12      1400
# 81    10/5/2020  ASTON MARTIN       3.5         10      1600
# 95    10/5/2020    LABORGUINI       3.0         12      1200
# 96    10/5/2020       FERRARI       3.0         12      1400
# 97    10/5/2020  ASTON MARTIN       3.5         10      1600
# 104   10/6/2020  ASTON MARTIN       3.5         10      1600
# 111   10/6/2020       FERRARI       3.0         12      1400
# 112   10/6/2020  ASTON MARTIN       3.5         10      1600
# 132   10/6/2020    LABORGUINI       3.0         12      1200
# 133   10/6/2020       FERRARI       3.0         12      1400
# 134   10/6/2020  ASTON MARTIN       3.5         10      1600
# 148   10/7/2020    LABORGUINI       3.0         12      1200
# 149   10/7/2020       FERRARI       3.0         12      1400
# 150   10/7/2020  ASTON MARTIN       3.5         10      1600
# 157   10/7/2020  ASTON MARTIN       3.5         10      1600
# 164   10/8/2020    LABORGUINI       3.0         12      1200
# 165   10/8/2020       FERRARI       3.0         12      1400
# 166   10/8/2020  ASTON MARTIN       3.5         10      1600
# 186   10/8/2020    LABORGUINI       3.0         12      1200
# 187   10/8/2020       FERRARI       3.0         12      1400
# 188   10/8/2020  ASTON MARTIN       3.5         10      1600
# 199   10/8/2020    LABORGUINI       3.0         12      1200
# 200   10/8/2020       FERRARI       3.0         12      1400
# 201   10/8/2020  ASTON MARTIN       3.5         10      1600
# 221   10/8/2020    LABORGUINI       3.0         12      1200
# 222   10/8/2020       FERRARI       3.0         12      1400
# 223   10/8/2020  ASTON MARTIN       3.5         10      1600
# 243   10/8/2020    LABORGUINI       3.0         12      1200
# 244   10/8/2020       FERRARI       3.0         12      1400
# 245   10/8/2020  ASTON MARTIN       3.5         10      1600
# 259   10/9/2020    LABORGUINI       3.0         12      1200
# 260   10/9/2020       FERRARI       3.0         12      1400
# 261   10/9/2020  ASTON MARTIN       3.5         10      1600
# 268   10/9/2020  ASTON MARTIN       3.5         10      1600
# 275   10/9/2020       FERRARI       3.0         12      1400
# 276   10/9/2020  ASTON MARTIN       3.5         10      1600
# 296  10/10/2020    LABORGUINI       3.0         12      1200
# 297  10/10/2020       FERRARI       3.0         12      1400
# 298  10/10/2020  ASTON MARTIN       3.5         10      1600
# 312  10/10/2020    LABORGUINI       3.0         12      1200
# 313  10/10/2020       FERRARI       3.0         12      1400
# 314  10/10/2020  ASTON MARTIN       3.5         10      1600
# 321  10/10/2020  ASTON MARTIN       3.5         10      1600
# 328  10/10/2020    LABORGUINI       3.0         12      1200
# 329  10/10/2020       FERRARI       3.0         12      1400
# 330  10/10/2020  ASTON MARTIN       3.5         10      1600
# 350  10/10/2020    LABORGUINI       3.0         12      1200
# 351  10/10/2020       FERRARI       3.0         12      1400
# 352  10/10/2020  ASTON MARTIN       3.5         10      1600
# 363  10/10/2020    LABORGUINI       3.0         12      1200
# 364  10/10/2020       FERRARI       3.0         12      1400
# 365  10/10/2020  ASTON MARTIN       3.5         10      1600
# 385  10/11/2020    LABORGUINI       3.0         12      1200
# 386  10/11/2020       FERRARI       3.0         12      1400
# 387  10/11/2020  ASTON MARTIN       3.5         10      1600
# 407  10/11/2020    LABORGUINI       3.0         12      1200
# 408  10/11/2020       FERRARI       3.0         12      1400
# 409  10/11/2020  ASTON MARTIN       3.5         10      1600
# 423  10/12/2020    LABORGUINI       3.0         12      1200
# 424  10/12/2020       FERRARI       3.0         12      1400
# 425  10/12/2020  ASTON MARTIN       3.5         10      1600
# 432  10/12/2020  ASTON MARTIN       3.5         10      1600
# 439  10/12/2020       FERRARI       3.0         12      1400
# 440  10/12/2020  ASTON MARTIN       3.5         10      1600
# 460   10/1/2021    LABORGUINI       3.0         12      1200
# 461   10/1/2021       FERRARI       3.0         12      1400
# 462   10/1/2021  ASTON MARTIN       3.5         10      1600
# 476   10/2/2021    LABORGUINI       3.0         12      1200
# 477   10/2/2021       FERRARI       3.0         12      1400
# 478   10/2/2021  ASTON MARTIN       3.5         10      1600
# 485   10/3/2021  ASTON MARTIN       3.5         10      1600
# 492   10/3/2021    LABORGUINI       3.0         12      1200
# 493   10/3/2021       FERRARI       3.0         12      1400
# 494   10/3/2021  ASTON MARTIN       3.5         10      1600
# 514   10/4/2021    LABORGUINI       3.0         12      1200
# 515   10/4/2021       FERRARI       3.0         12      1400
# 516   10/4/2021  ASTON MARTIN       3.5         10      1600
# 527   10/4/2021    LABORGUINI       3.0         12      1200
# 528   10/5/2021       FERRARI       3.0         12      1400
# 529   10/5/2021  ASTON MARTIN       3.5         10      1600
# 549   10/5/2021    LABORGUINI       3.0         12      1200
# 550   10/5/2021       FERRARI       3.0         12      1400
# 551   10/5/2021  ASTON MARTIN       3.5         10      1600
# 571   10/6/2021    LABORGUINI       3.0         12      1200
# 572   10/6/2021       FERRARI       3.0         12      1400
# 573   10/6/2021  ASTON MARTIN       3.5         10      1600
# 587   10/6/2021    LABORGUINI       3.0         12      1200
# 588   10/6/2021       FERRARI       3.0         12      1400
# 589   10/6/2021  ASTON MARTIN       3.5         10      1600
# 596   10/6/2021  ASTON MARTIN       3.5         10      1600
# 603   10/7/2021       FERRARI       3.0         12      1400
# 604   10/7/2021  ASTON MARTIN       3.5         10      1600
# 624   10/8/2021    LABORGUINI       3.0         12      1200
# 625   10/8/2021       FERRARI       3.0         12      1400
# 626   10/8/2021  ASTON MARTIN       3.5         10      1600
# 640   10/8/2021    LABORGUINI       3.0         12      1200
# 641   10/8/2021       FERRARI       3.0         12      1400
# 642   10/8/2021  ASTON MARTIN       3.5         10      1600
# 649   10/8/2021  ASTON MARTIN       3.5         10      1600
# 656   10/8/2021    LABORGUINI       3.0         12      1200
# 657   10/8/2021       FERRARI       3.0         12      1400
# 658   10/8/2021  ASTON MARTIN       3.5         10      1600
# 678   10/8/2021    LABORGUINI       3.0         12      1200
# 679   10/8/2021       FERRARI       3.0         12      1400
# 680   10/8/2021  ASTON MARTIN       3.5         10      1600
# 691   10/8/2021    LABORGUINI       3.0         12      1200
# 692   10/8/2021       FERRARI       3.0         12      1400
# 693   10/8/2021  ASTON MARTIN       3.5         10      1600
# 713   10/9/2021    LABORGUINI       3.0         12      1200
# 714   10/9/2021       FERRARI       3.0         12      1400
# 715   10/9/2021  ASTON MARTIN       3.5         10      1600
# 735   10/9/2021    LABORGUINI       3.0         12      1200
# 736   10/9/2021       FERRARI       3.0         12      1400
# 737   10/9/2021  ASTON MARTIN       3.5         10      1600
# 751  10/10/2021    LABORGUINI       3.0         12      1200
# 752  10/10/2021       FERRARI       3.0         12      1400
# 753  10/10/2021  ASTON MARTIN       3.5         10      1600
# 760  10/10/2021  ASTON MARTIN       3.5         10      1600
# 767  10/10/2021       FERRARI       3.0         12      1400
# 768  10/10/2021  ASTON MARTIN       3.5         10      1600
# 788  10/10/2021    LABORGUINI       3.0         12      1200
# 789  10/10/2021       FERRARI       3.0         12      1400
# 790  10/10/2021  ASTON MARTIN       3.5         10      1600
# 804  10/10/2021    LABORGUINI       3.0         12      1200
# 805  10/10/2021       FERRARI       3.0         12      1400
# 806  10/10/2021  ASTON MARTIN       3.5         10      1600
# 813  10/10/2021  ASTON MARTIN       3.5         10      1600
# 820  10/10/2021    LABORGUINI       3.0         12      1200
# 821  10/10/2021       FERRARI       3.0         12      1400
# 822  10/10/2021  ASTON MARTIN       3.5         10      1600
# 842  10/11/2021    LABORGUINI       3.0         12      1200
# 843  10/11/2021       FERRARI       3.0         12      1400
# 844  10/11/2021  ASTON MARTIN       3.5         10      1600
# 855  10/11/2021    LABORGUINI       3.0         12      1200
# 856  10/11/2021       FERRARI       3.0         12      1400
# 857  10/11/2021  ASTON MARTIN       3.5         10      1600
# 877  10/12/2021    LABORGUINI       3.0         12      1200
# 878  10/12/2021       FERRARI       3.0         12      1400
# 879  10/12/2021  ASTON MARTIN       3.5         10      1600
# 899  10/12/2021    LABORGUINI       3.0         12      1200
# 900  10/12/2021       FERRARI       3.0         12      1400
# 901  10/12/2021  ASTON MARTIN       3.5         10      1600
# 915  10/12/2021    LABORGUINI       3.0         12      1200
# 916  10/12/2021       FERRARI       3.0         12      1400
# 917  10/12/2021  ASTON MARTIN       3.5         10      1600
# 924  10/12/2021  ASTON MARTIN       3.5         10      1600
# 931  10/12/2021       FERRARI       3.0         12      1400
# 932  10/12/2021  ASTON MARTIN       3.5         10      1600
# 952  10/12/2021    LABORGUINI       3.0         12      1200
# 953  10/12/2021       FERRARI       3.0         12      1400
# 954  10/12/2021  ASTON MARTIN       3.5         10      1600
# 968  10/12/2021    LABORGUINI       3.0         12      1200
# 969  10/12/2021       FERRARI       3.0         12      1400
# 970  10/12/2021  ASTON MARTIN       3.5         10      1600
# 977  10/12/2021  ASTON MARTIN       3.5         10      1600
#
#      VELOCIDADE_MAXIMA(KM/H)  CAVALOS TRANSMISSAO   VALOR  CATEGORIA
# 0                        360      700  AUTOMATICO  900000  IMPORTADO
# 1                        360      640  AUTOMATICO  900000  IMPORTADO
# 2                        360      620  AUTOMATICO  900000  IMPORTADO
# 22                       360      700  AUTOMATICO  900000  IMPORTADO
# 23                       360      640  AUTOMATICO  900000  IMPORTADO
# 24                       360      620  AUTOMATICO  900000  IMPORTADO
# 35                       360      700  AUTOMATICO  900000  IMPORTADO
# 36                       360      640  AUTOMATICO  900000  IMPORTADO
# 37                       360      620  AUTOMATICO  900000  IMPORTADO
# 57                       360      700  AUTOMATICO  900000  IMPORTADO
# 58                       360      640  AUTOMATICO  900000  IMPORTADO
# 59                       360      620  AUTOMATICO  900000  IMPORTADO
# 79                       360      700  AUTOMATICO  900000  IMPORTADO
# 80                       360      640  AUTOMATICO  900000  IMPORTADO
# 81                       360      620  AUTOMATICO  900000  IMPORTADO
# 95                       360      700  AUTOMATICO  900000  IMPORTADO
# 96                       360      640  AUTOMATICO  900000  IMPORTADO
# 97                       360      620  AUTOMATICO  900000  IMPORTADO
# 104                      360      620  AUTOMATICO  900000  IMPORTADO
# 111                      360      640  AUTOMATICO  900000  IMPORTADO
# 112                      360      620  AUTOMATICO  900000  IMPORTADO
# 132                      360      700  AUTOMATICO  900000  IMPORTADO
# 133                      360      640  AUTOMATICO  900000  IMPORTADO
# 134                      360      620  AUTOMATICO  900000  IMPORTADO
# 148                      360      700  AUTOMATICO  900000  IMPORTADO
# 149                      360      640  AUTOMATICO  900000  IMPORTADO
# 150                      360      620  AUTOMATICO  900000  IMPORTADO
# 157                      360      620  AUTOMATICO  900000  IMPORTADO
# 164                      360      700  AUTOMATICO  900000  IMPORTADO
# 165                      360      640  AUTOMATICO  900000  IMPORTADO
# 166                      360      620  AUTOMATICO  900000  IMPORTADO
# 186                      360      700  AUTOMATICO  900000  IMPORTADO
# 187                      360      640  AUTOMATICO  900000  IMPORTADO
# 188                      360      620  AUTOMATICO  900000  IMPORTADO
# 199                      360      700  AUTOMATICO  900000  IMPORTADO
# 200                      360      640  AUTOMATICO  900000  IMPORTADO
# 201                      360      620  AUTOMATICO  900000  IMPORTADO
# 221                      360      700  AUTOMATICO  900000  IMPORTADO
# 222                      360      640  AUTOMATICO  900000  IMPORTADO
# 223                      360      620  AUTOMATICO  900000  IMPORTADO
# 243                      360      700  AUTOMATICO  900000  IMPORTADO
# 244                      360      640  AUTOMATICO  900000  IMPORTADO
# 245                      360      620  AUTOMATICO  900000  IMPORTADO
# 259                      360      700  AUTOMATICO  900000  IMPORTADO
# 260                      360      640  AUTOMATICO  900000  IMPORTADO
# 261                      360      620  AUTOMATICO  900000  IMPORTADO
# 268                      360      620  AUTOMATICO  900000  IMPORTADO
# 275                      360      640  AUTOMATICO  900000  IMPORTADO
# 276                      360      620  AUTOMATICO  900000  IMPORTADO
# 296                      360      700  AUTOMATICO  900000  IMPORTADO
# 297                      360      640  AUTOMATICO  900000  IMPORTADO
# 298                      360      620  AUTOMATICO  900000  IMPORTADO
# 312                      360      700  AUTOMATICO  900000  IMPORTADO
# 313                      360      640  AUTOMATICO  900000  IMPORTADO
# 314                      360      620  AUTOMATICO  900000  IMPORTADO
# 321                      360      620  AUTOMATICO  900000  IMPORTADO
# 328                      360      700  AUTOMATICO  900000  IMPORTADO
# 329                      360      640  AUTOMATICO  900000  IMPORTADO
# 330                      360      620  AUTOMATICO  900000  IMPORTADO
# 350                      360      700  AUTOMATICO  900000  IMPORTADO
# 351                      360      640  AUTOMATICO  900000  IMPORTADO
# 352                      360      620  AUTOMATICO  900000  IMPORTADO
# 363                      360      700  AUTOMATICO  900000  IMPORTADO
# 364                      360      640  AUTOMATICO  900000  IMPORTADO
# 365                      360      620  AUTOMATICO  900000  IMPORTADO
# 385                      360      700  AUTOMATICO  900000  IMPORTADO
# 386                      360      640  AUTOMATICO  900000  IMPORTADO
# 387                      360      620  AUTOMATICO  900000  IMPORTADO
# 407                      360      700  AUTOMATICO  900000  IMPORTADO
# 408                      360      640  AUTOMATICO  900000  IMPORTADO
# 409                      360      620  AUTOMATICO  900000  IMPORTADO
# 423                      360      700  AUTOMATICO  900000  IMPORTADO
# 424                      360      640  AUTOMATICO  900000  IMPORTADO
# 425                      360      620  AUTOMATICO  900000  IMPORTADO
# 432                      360      620  AUTOMATICO  900000  IMPORTADO
# 439                      360      640  AUTOMATICO  900000  IMPORTADO
# 440                      360      620  AUTOMATICO  900000  IMPORTADO
# 460                      360      700  AUTOMATICO  900000  IMPORTADO
# 461                      360      640  AUTOMATICO  900000  IMPORTADO
# 462                      360      620  AUTOMATICO  900000  IMPORTADO
# 476                      360      700  AUTOMATICO  900000  IMPORTADO
# 477                      360      640  AUTOMATICO  900000  IMPORTADO
# 478                      360      620  AUTOMATICO  900000  IMPORTADO
# 485                      360      620  AUTOMATICO  900000  IMPORTADO
# 492                      360      700  AUTOMATICO  900000  IMPORTADO
# 493                      360      640  AUTOMATICO  900000  IMPORTADO
# 494                      360      620  AUTOMATICO  900000  IMPORTADO
# 514                      360      700  AUTOMATICO  900000  IMPORTADO
# 515                      360      640  AUTOMATICO  900000  IMPORTADO
# 516                      360      620  AUTOMATICO  900000  IMPORTADO
# 527                      360      700  AUTOMATICO  900000  IMPORTADO
# 528                      360      640  AUTOMATICO  900000  IMPORTADO
# 529                      360      620  AUTOMATICO  900000  IMPORTADO
# 549                      360      700  AUTOMATICO  900000  IMPORTADO
# 550                      360      640  AUTOMATICO  900000  IMPORTADO
# 551                      360      620  AUTOMATICO  900000  IMPORTADO
# 571                      360      700  AUTOMATICO  900000  IMPORTADO
# 572                      360      640  AUTOMATICO  900000  IMPORTADO
# 573                      360      620  AUTOMATICO  900000  IMPORTADO
# 587                      360      700  AUTOMATICO  900000  IMPORTADO
# 588                      360      640  AUTOMATICO  900000  IMPORTADO
# 589                      360      620  AUTOMATICO  900000  IMPORTADO
# 596                      360      620  AUTOMATICO  900000  IMPORTADO
# 603                      360      640  AUTOMATICO  900000  IMPORTADO
# 604                      360      620  AUTOMATICO  900000  IMPORTADO
# 624                      360      700  AUTOMATICO  900000  IMPORTADO
# 625                      360      640  AUTOMATICO  900000  IMPORTADO
# 626                      360      620  AUTOMATICO  900000  IMPORTADO
# 640                      360      700  AUTOMATICO  900000  IMPORTADO
# 641                      360      640  AUTOMATICO  900000  IMPORTADO
# 642                      360      620  AUTOMATICO  900000  IMPORTADO
# 649                      360      620  AUTOMATICO  900000  IMPORTADO
# 656                      360      700  AUTOMATICO  900000  IMPORTADO
# 657                      360      640  AUTOMATICO  900000  IMPORTADO
# 658                      360      620  AUTOMATICO  900000  IMPORTADO
# 678                      360      700  AUTOMATICO  900000  IMPORTADO
# 679                      360      640  AUTOMATICO  900000  IMPORTADO
# 680                      360      620  AUTOMATICO  900000  IMPORTADO
# 691                      360      700  AUTOMATICO  900000  IMPORTADO
# 692                      360      640  AUTOMATICO  900000  IMPORTADO
# 693                      360      620  AUTOMATICO  900000  IMPORTADO
# 713                      360      700  AUTOMATICO  900000  IMPORTADO
# 714                      360      640  AUTOMATICO  900000  IMPORTADO
# 715                      360      620  AUTOMATICO  900000  IMPORTADO
# 735                      360      700  AUTOMATICO  900000  IMPORTADO
# 736                      360      640  AUTOMATICO  900000  IMPORTADO
# 737                      360      620  AUTOMATICO  900000  IMPORTADO
# 751                      360      700  AUTOMATICO  900000  IMPORTADO
# 752                      360      640  AUTOMATICO  900000  IMPORTADO
# 753                      360      620  AUTOMATICO  900000  IMPORTADO
# 760                      360      620  AUTOMATICO  900000  IMPORTADO
# 767                      360      640  AUTOMATICO  900000  IMPORTADO
# 768                      360      620  AUTOMATICO  900000  IMPORTADO
# 788                      360      700  AUTOMATICO  900000  IMPORTADO
# 789                      360      640  AUTOMATICO  900000  IMPORTADO
# 790                      360      620  AUTOMATICO  900000  IMPORTADO
# 804                      360      700  AUTOMATICO  900000  IMPORTADO
# 805                      360      640  AUTOMATICO  900000  IMPORTADO
# 806                      360      620  AUTOMATICO  900000  IMPORTADO
# 813                      360      620  AUTOMATICO  900000  IMPORTADO
# 820                      360      700  AUTOMATICO  900000  IMPORTADO
# 821                      360      640  AUTOMATICO  900000  IMPORTADO
# 822                      360      620  AUTOMATICO  900000  IMPORTADO
# 842                      360      700  AUTOMATICO  900000  IMPORTADO
# 843                      360      640  AUTOMATICO  900000  IMPORTADO
# 844                      360      620  AUTOMATICO  900000  IMPORTADO
# 855                      360      700  AUTOMATICO  900000  IMPORTADO
# 856                      360      640  AUTOMATICO  900000  IMPORTADO
# 857                      360      620  AUTOMATICO  900000  IMPORTADO
# 877                      360      700  AUTOMATICO  900000  IMPORTADO
# 878                      360      640  AUTOMATICO  900000  IMPORTADO
# 879                      360      620  AUTOMATICO  900000  IMPORTADO
# 899                      360      700  AUTOMATICO  900000  IMPORTADO
# 900                      360      640  AUTOMATICO  900000  IMPORTADO
# 901                      360      620  AUTOMATICO  900000  IMPORTADO
# 915                      360      700  AUTOMATICO  900000  IMPORTADO
# 916                      360      640  AUTOMATICO  900000  IMPORTADO
# 917                      360      620  AUTOMATICO  900000  IMPORTADO
# 924                      360      620  AUTOMATICO  900000  IMPORTADO
# 931                      360      640  AUTOMATICO  900000  IMPORTADO
# 932                      360      620  AUTOMATICO  900000  IMPORTADO
# 952                      360      700  AUTOMATICO  900000  IMPORTADO
# 953                      360      640  AUTOMATICO  900000  IMPORTADO
# 954                      360      620  AUTOMATICO  900000  IMPORTADO
# 968                      360      700  AUTOMATICO  900000  IMPORTADO
# 969                      360      640  AUTOMATICO  900000  IMPORTADO
# 970                      360      620  AUTOMATICO  900000  IMPORTADO
# 977                      360      620  AUTOMATICO  900000  IMPORTADO

# %%
# Aqui podemos observar a quantidade de registros por tipo de transmissao

df_dados.groupby(['TRANSMISSAO']).size()
# Out:
# TRANSMISSAO
# AUTOMATICO    534
# MANUAL        450
# dtype: int64

# %%
# Aqui podemos observar a quantidade de registros por tipo de categoria

df_dados.groupby(['CATEGORIA']).size()
# Out:
# CATEGORIA
# IMPORTADO    402
# NACIONAL     582
# dtype: int64

# %%
# Aqui podemos observar a quantidade de registros por potencia(cavalos)

df_dados.groupby(['CAVALOS']).size()
# Out:
# CAVALOS
# 116     66
# 118    486
# 190     36
# 210     24
# 230     30
# 250     36
# 280     36
# 340     36
# 480     66
# 620     66
# 640     54
# 700     48
# dtype: int64

# %%
# Aqui podemos observar a quantidade de registros por cilindros

df_dados.groupby(['CILINDROS']).size()
# Out:
# CILINDROS
# 3      30
# 4     480
# 6     168
# 8     138
# 10     66
# 12    102
# dtype: int64

# %%
# Podemos observar as informações acima, todas de uma vez através de gráficos
# plt.rcParams["figure.autolayout"] - ajusta automaticamente o layout dos gráficos para evitar sobreposição de elementos.
# Countplot é um gráfico de barras da biblioteca Seaborn (baseado no Matplotlib) que conta e exibe a frequência de valores 
# categóricos em uma variável. É especialmente útil para visualizar distribuições de dados discretos (como categorias, grupos ou rótulos).

plt.rcParams["figure.figsize"] = [10.00, 8.00]
plt.rcParams["figure.autolayout"] = True
f, axes = plt.subplots(2, 2)

sns.countplot(data = df_dados, x="CILINDROS", ax=axes[0][0])
sns.countplot(data = df_dados, x="CAVALOS", ax=axes[0][1])
sns.countplot(data = df_dados, x="TRANSMISSAO", ax=axes[1][0])
sns.countplot(data = df_dados, x="CATEGORIA", ax=axes[1][1])

plt.show()

# %%
# Boxplots
# Boxplot é utilizado para avaliar e comparar o formato, tendência central e variabilidade de distribuições de amostra, 
# e para procurar por outliers. Por padrão, um boxplot demonstra a mediana, os quartis, 
# o intervalo interquartil(IQR) e outliers para cada variável. 

# Outlier são valores que estão bem discrepantes dentro do conjunto de dados, podem ser para mais ou para menos. Observe abaixo
# que há 2 pontinhos no boxplot, que seriam os valores outliers.
# plt.gcf().set_size_inches(4, 3) - Utilizado para redimensionar o tamanho do gráfico. 

sns.boxplot(data = df_dados, y = "VALOR")
plt.gcf().set_size_inches(4, 3)
plt.show()

# %%
# Histogramas
# Um histograma é uma visualização gráfica de dados usando barras de diferentes alturas. 
# Em um histograma, cada barra agrupa números em intervalos. 
# As barras mais altas mostram que mais dados estão nesse intervalo. Um histograma exibe a forma e distribuição de dados 
# amostrais discretos ou contínuos.

sns.histplot(df_dados['VALOR'])
plt.gcf().set_size_inches(4, 3)
plt.show()

# %%
# Correlação
# A correção é utilizada para entender como as variaveis se relacionam entre si.
# A correção vai de -1 até +1 onde -1 significa uma forte correção negativa e +1 significa uma forte correlação positiva.
# Correlação NÃO é causalidade, ou seja, uma relação entre as variaveis não significa que uma é a causa do valor da outra.
# numeric_df = df_dados.select_dtypes(include=['number']) - Seleciona apenas colunas numéricas do DataFrame
# O heatmap (mapa de calor) é um gráfico que representa valores numéricos usando cores em uma matriz. 
# Quando usado com a função .corr() do Pandas, ele mostra a correlação entre variáveis numéricas de um DataFrame.

numeric_df = df_dados.select_dtypes(include=['number'])

plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['font.size'] = 10 
plt.rcParams['axes.titlesize'] = 20
plt.rcParams["figure.figsize"] = [8.00, 8.00]
plt.rcParams["figure.autolayout"] = True

sns.heatmap(numeric_df.corr(), annot=True)
plt.gcf().set_size_inches(7, 7)
plt.show()

# %%
# Scater-Plot ou Gráfico de Dispersão
# Esse gráfico pode ser utilizado para comprovar a correção das variáveis e também visualizar como as mesmas se relacionam
# Observe que a medida que os CAVALOS DE POTENCIA aumentam, o valor do carro também aumenta.
# Observe que neste caso temos uma forte correção positiva.

sns.scatterplot(data = df_dados, x = "CAVALOS", y = "VALOR")
plt.gcf().set_size_inches(4, 4)
plt.show()

# %%
# carregar variaveis para plot

variaveis_numericas = []
for i in df_dados.columns[0:11].tolist():
        if df_dados.dtypes[i] == 'int64' or df_dados.dtypes[i] == 'float64':            
            print(i, ':' , df_dados.dtypes[i]) 
            variaveis_numericas.append(i)
 
    
    
    
plt.rcParams["figure.figsize"] = [14.00, 10.00]
plt.rcParams["figure.autolayout"] = True

plt.rcParams['font.size'] = 10 
plt.rcParams['axes.titlesize'] = 20

f, axes = plt.subplots(2, 3) #8 linhas e 4 colunas

linha = 0
coluna = 0
for i in variaveis_numericas:
    sns.boxplot(data = df_dados, y=i, ax=axes[linha][coluna])
    coluna += 1
    if coluna == 3:
        linha += 1
        coluna = 0            

plt.show()
# Out:
# KM-LITRO : float64
# CILINDROS : int64
# PESO(KG) : int64
# VELOCIDADE_MAXIMA(KM/H) : int64
# CAVALOS : int64
# VALOR : int64

# %%
# carregar variaveis para plot

variaveis_numericas = []
for i in df_dados.columns[0:11].tolist():
        if df_dados.dtypes[i] == 'int64' or df_dados.dtypes[i] == 'float64':            
            print(i, ':' , df_dados.dtypes[i]) 
            variaveis_numericas.append(i)
    
    
    
plt.rcParams["figure.figsize"] = [14.00, 10.00]
plt.rcParams["figure.autolayout"] = True

plt.rcParams['font.size'] = 10 
plt.rcParams['axes.titlesize'] = 20



f, axes = plt.subplots(2, 3) #8 linhas e 4 colunas

linha = 0
coluna = 0
for i in variaveis_numericas:
    sns.histplot(data = df_dados, x=i, ax=axes[linha][coluna])
    coluna += 1
    if coluna == 3:
        linha += 1
        coluna = 0            

plt.show()
# Out:
# KM-LITRO : float64
# CILINDROS : int64
# PESO(KG) : int64
# VELOCIDADE_MAXIMA(KM/H) : int64
# CAVALOS : int64
# VALOR : int64

# %%
# Identificando os modelos mais vendidos

x = df_dados['MODELO'].value_counts().values
y = df_dados['MODELO'].value_counts().index

plt.gcf().set_size_inches(7,5)
sns.barplot( x=x, y=y ) 
plt.show()

# %%
#Agora podemos exibir um gráfico comparativo entre as vendas de 2020 e 2021

# Reiniciando o matplotlib
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# Formatando tamanho do grafico
plt.gcf().set_size_inches(7,4)

#Convertendo o campo DATA_VENDA para DateTime
df_dados['DATA_VENDA'] = pd.to_datetime(df_dados['DATA_VENDA'], format="%d/%m/%Y")

#Selecionando apenas as vendas de 2021
df_2020 = df_dados[df_dados["DATA_VENDA"].dt.year == 2020]

#Selecionando apenas as vendas de 2021
df_2021 = df_dados[df_dados["DATA_VENDA"].dt.year == 2021]

# Comparativo de lucro bruto por mês
df_2020.groupby(df_2020["DATA_VENDA"].dt.month)["VALOR"].sum().plot(color='red', label='Ano 2020')
df_2021.groupby(df_2021["DATA_VENDA"].dt.month)["VALOR"].sum().plot(color='green', label='Ano 2021')
plt.title("Vendas x Mês")
plt.ylabel("Valor")
plt.xlabel("Mês")

plt.legend()
plt.show()

# %%
# Este código realiza uma agregação de vendas mensais a partir de um DataFrame (df_2020), somando os valores de vendas (VALOR) para cada mês do ano.
# df_2020["DATA_VENDA"].dt.month - Extrai o mês (1 a 12) da coluna DATA_VENDA (que deve ser do tipo datetime).
# .groupby(...): - Agrupa o DataFrame pelos meses extraídos (ou seja, os dados serão agregados por mês).
# .agg({"VALOR": "sum"}) - Calcula a soma total dos valores de venda (VALOR) para cada grupo (mês).
# .style.format("{:,.2f}") - Formata os números para exibir, 2 casas decimais (:.2f). Separador de milhares (,), ex: 1,000.50.

df_2020.groupby(df_2020["DATA_VENDA"].dt.month).agg({"VALOR": "sum"}).style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c60a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c60a1_level0_col0" class="col_heading level0 col0" >VALOR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DATA_VENDA</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c60a1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c60a1_row0_col0" class="data row0 col0" >4,353,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c60a1_row1_col0" class="data row1 col0" >4,991,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c60a1_row2_col0" class="data row2 col0" >9,037,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c60a1_row3_col0" class="data row3 col0" >1,829,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c60a1_row4_col0" class="data row4 col0" >10,273,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c60a1_row5_col0" class="data row5 col0" >11,602,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c60a1_row6_col0" class="data row6 col0" >6,640,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_c60a1_row7_col0" class="data row7 col0" >24,045,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_c60a1_row8_col0" class="data row8 col0" >12,171,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_c60a1_row9_col0" class="data row9 col0" >26,254,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_c60a1_row10_col0" class="data row10 col0" >11,220,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c60a1_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_c60a1_row11_col0" class="data row11 col0" >11,299,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Este código realiza uma agregação dos valores de venda (VALOR) por mês a partir do DataFrame df_2021.

df_2021.groupby(df_2021["DATA_VENDA"].dt.month)["VALOR"].sum()
# Out:
# DATA_VENDA
# 1      4881000
# 2      5120000
# 3      8124000
# 4      5253000
# 5      8734000
# 6     12712000
# 7      3901000
# 8     26448000
# 9     11086000
# 10    27152000
# 11    10550000
# 12    34675000
# Name: VALOR, dtype: int64

# %%
#df_2020['DATA_VENDA'] = df_2020['DATA_VENDA'].dt.strftime('%m-%Y')
#df_2021.groupby(df_2021["DATA_VENDA"].dt.month).agg({"VALOR": "sum"}).style.format("{:,.2f}")

(df_2021.groupby(df_2021["DATA_VENDA"].dt.strftime('%m-%Y')).agg({"VALOR": "sum"}).style.format("{:,.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_27916">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27916_level0_col0" class="col_heading level0 col0" >VALOR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DATA_VENDA</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27916_level0_row0" class="row_heading level0 row0" >01-2021</th>
#       <td id="T_27916_row0_col0" class="data row0 col0" >4,881,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row1" class="row_heading level0 row1" >02-2021</th>
#       <td id="T_27916_row1_col0" class="data row1 col0" >5,120,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row2" class="row_heading level0 row2" >03-2021</th>
#       <td id="T_27916_row2_col0" class="data row2 col0" >8,124,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row3" class="row_heading level0 row3" >04-2021</th>
#       <td id="T_27916_row3_col0" class="data row3 col0" >5,253,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row4" class="row_heading level0 row4" >05-2021</th>
#       <td id="T_27916_row4_col0" class="data row4 col0" >8,734,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row5" class="row_heading level0 row5" >06-2021</th>
#       <td id="T_27916_row5_col0" class="data row5 col0" >12,712,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row6" class="row_heading level0 row6" >07-2021</th>
#       <td id="T_27916_row6_col0" class="data row6 col0" >3,901,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row7" class="row_heading level0 row7" >08-2021</th>
#       <td id="T_27916_row7_col0" class="data row7 col0" >26,448,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row8" class="row_heading level0 row8" >09-2021</th>
#       <td id="T_27916_row8_col0" class="data row8 col0" >11,086,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row9" class="row_heading level0 row9" >10-2021</th>
#       <td id="T_27916_row9_col0" class="data row9 col0" >27,152,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row10" class="row_heading level0 row10" >11-2021</th>
#       <td id="T_27916_row10_col0" class="data row10 col0" >10,550,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_27916_level0_row11" class="row_heading level0 row11" >12-2021</th>
#       <td id="T_27916_row11_col0" class="data row11 col0" >34,675,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
def formata_valores(valor, pos):
    """
    Transforma grandes valores (na casa dos bilhões, milhões e milhares), como 4500 em 4,5 K e também transforma adequadamente 4000 
    em 4 K (sem zero após o decimal).
    """
    
    if valor >= 1000000000:
        val = round(valor/1000000000, 1)
        novo_valor_formatado = '{:}B'.format(val)
    elif valor >= 1000000:
        val = round(valor/1000000, 1)
        novo_valor_formatado = '{:}M'.format(val)
    elif valor >= 1000:
        val = round(valor/1000, 1)
        novo_valor_formatado = '{:}K'.format(val)
    elif valor < 1000:
        novo_valor_formatado = round(valor, 1)
    else:
        novo_valor_formatado = valor

    # make new_tick_format into a string value
    novo_valor_formatado = str(novo_valor_formatado)
    
    # code below will keep 4.5M as is but change values such as 4.0M to 4M since that zero after the decimal isn't needed
    index_of_decimal = novo_valor_formatado.find(".")
    
    if index_of_decimal != -1:
        value_after_decimal = novo_valor_formatado[index_of_decimal+1]
        if value_after_decimal == "0":
            # remove the 0 after the decimal point since it's not needed
            novo_valor_formatado = novo_valor_formatado[0:index_of_decimal] + novo_valor_formatado[index_of_decimal+2:]
            
    return novo_valor_formatado

# %%
# df_2021.groupby(df_2021["DATA_VENDA"].dt.month)["VALOR"].sum().plot.bar(color='blue', label='Ano 2021')
import matplotlib.ticker as tick

df_2021.groupby(df_2021["DATA_VENDA"].dt.strftime('%m-%Y'))["VALOR"].sum().plot.bar(color='blue', label='Ano 2021')
plt.gcf().set_size_inches(7,4)

plt.ticklabel_format(style='plain', axis='y')
plt.title("Vendas x Mês")
plt.ylabel("Valor")
plt.xlabel("Mês")
plt.legend()
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(formata_valores));

# %%
df_2021.groupby(['DATA_VENDA'], as_index=False)['VALOR'].sum()
# Out:
#    DATA_VENDA     VALOR
# 0  2021-01-10   4881000
# 1  2021-02-10   5120000
# 2  2021-03-10   8124000
# 3  2021-04-10   5253000
# 4  2021-05-10   8734000
# 5  2021-06-10  12712000
# 6  2021-07-10   3901000
# 7  2021-08-10  26448000
# 8  2021-09-10  11086000
# 9  2021-10-10  27152000
# 10 2021-11-10  10550000
# 11 2021-12-10  34675000

# %%
df_2021.groupby(['DATA_VENDA']).agg({"VALOR": "sum"}).style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_13e04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13e04_level0_col0" class="col_heading level0 col0" >VALOR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DATA_VENDA</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13e04_level0_row0" class="row_heading level0 row0" >2021-01-10 00:00:00</th>
#       <td id="T_13e04_row0_col0" class="data row0 col0" >4,881,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row1" class="row_heading level0 row1" >2021-02-10 00:00:00</th>
#       <td id="T_13e04_row1_col0" class="data row1 col0" >5,120,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row2" class="row_heading level0 row2" >2021-03-10 00:00:00</th>
#       <td id="T_13e04_row2_col0" class="data row2 col0" >8,124,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row3" class="row_heading level0 row3" >2021-04-10 00:00:00</th>
#       <td id="T_13e04_row3_col0" class="data row3 col0" >5,253,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row4" class="row_heading level0 row4" >2021-05-10 00:00:00</th>
#       <td id="T_13e04_row4_col0" class="data row4 col0" >8,734,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row5" class="row_heading level0 row5" >2021-06-10 00:00:00</th>
#       <td id="T_13e04_row5_col0" class="data row5 col0" >12,712,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row6" class="row_heading level0 row6" >2021-07-10 00:00:00</th>
#       <td id="T_13e04_row6_col0" class="data row6 col0" >3,901,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row7" class="row_heading level0 row7" >2021-08-10 00:00:00</th>
#       <td id="T_13e04_row7_col0" class="data row7 col0" >26,448,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row8" class="row_heading level0 row8" >2021-09-10 00:00:00</th>
#       <td id="T_13e04_row8_col0" class="data row8 col0" >11,086,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row9" class="row_heading level0 row9" >2021-10-10 00:00:00</th>
#       <td id="T_13e04_row9_col0" class="data row9 col0" >27,152,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row10" class="row_heading level0 row10" >2021-11-10 00:00:00</th>
#       <td id="T_13e04_row10_col0" class="data row10 col0" >10,550,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_13e04_level0_row11" class="row_heading level0 row11" >2021-12-10 00:00:00</th>
#       <td id="T_13e04_row11_col0" class="data row11 col0" >34,675,000.00</td>
#     </tr>
#   </tbody>
# </table>
